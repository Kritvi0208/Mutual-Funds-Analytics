# %% [markdown]
# # 04. Performance Analytics & Risk Metrics
# Computes 1Yr/3Yr CAGRs, Sharpe, Sortino, Alpha, Beta, Max Drawdown, and Composite Scorecard.

# %%
import pandas as pd
from pathlib import Path
base = Path('.').resolve()
sc_path = base.parent / 'reports' / 'tables' / 'fund_scorecard.csv' if (base.parent / 'reports').exists() else base / 'reports' / 'tables' / 'fund_scorecard.csv'
if sc_path.exists():
    sc = pd.read_csv(sc_path)
    print('Top 3 Funds by Composite Scorecard:')
    print(sc[['fund_rank', 'scheme_name', 'scorecard_score', 'cagr_3yr_pct', 'sharpe_ratio']].head(3))
# Out:
# Top 3 Funds by Composite Scorecard:
#    fund_rank                                    scheme_name  scorecard_score  \
# 0          1  Mirae Asset Large Cap Fund - Regular - Growth           100.00
# 1          2       ICICI Pru Midcap Fund - Regular - Growth            95.26
# 2          3         Kotak Flexicap Fund - Regular - Growth            94.04
#
#    cagr_3yr_pct  sharpe_ratio
# 0         33.99          1.07
# 1         31.77          0.88
# 2         29.58          0.97
